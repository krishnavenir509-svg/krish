# %%
import numpy as np
a=np.array([25,5,9])
b=np.array([24,3,2])
sum=a+b
print("sum",sum)
sum=a-b
print("sum",sum)
sum=a*b
print("sum",sum)
sum=a/b
print("sum",sum)
# Out:
# sum [49  8 11]
# sum [1 2 7]
# sum [600  15  18]
# sum [1.04166667 1.66666667 4.5       ]

# %% [markdown]
# # New Section
