# %%
name="Shalini"

age = 19

CGPA=7.6

Placed=True

print("Student name", name)

print ("Age:", age)

print("CGPA:", CGPA)

print("Placed", Placed)

print (type (name))
# Out:
# Student name Shalini
# Age: 19
# CGPA: 7.6
# Placed True
# <class 'str'>

# %% [markdown]
# # New Section
