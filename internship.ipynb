# %%
import pandas as pd
df=pd.read_csv("Hospitaldata.csv")
df.head()
# shows last 5 rows
df.tail()
# Out:
#     Patient_ID  Age  Gender        Disease Admission_Date Discharge_Date  \
# 995      P0996   46    Male  Heart Disease     2025-03-05     2025-03-06
# 996      P0997   59    Male            Flu     2025-06-23     2025-06-27
# 997      P0998   74  Female         Dengue     2025-12-11     2025-12-14
# 998      P0999   25    Male         Asthma     2025-07-04     2025-07-12
# 999      P1000    8  Female         Dengue     2025-08-06     2025-08-09
#
#              Department        City  Treatment_Cost
# 995         Pulmonology       Salem        37106.08
# 996         Pulmonology  Coimbatore        33679.20
# 997    General Medicine  Coimbatore        26306.14
# 998  Infectious Disease      Trichy         5015.41
# 999  Infectious Disease     Madurai        19095.42

# %% [markdown]
# # New Section
